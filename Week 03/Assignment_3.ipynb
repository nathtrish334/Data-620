# %% [markdown]
# #<h1 align="center">Data 620<h1>
# <b><center>Trishita Nath</center></b> <br>
# <u><center>Week 3 Assignment</center></u>

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# Plotting parameters
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4

# %% [markdown]
# 1. Load a graph database of your choosing from a text file or other source. If you take a
# large network dataset from the web (such as from https://snap.stanford.edu/data/), please
# feel free at this point to load just a small subset of the nodes and edges.

# %% [markdown]
# Data source: https://snap.stanford.edu/data/soc-sign-bitcoinotc.csv.gz

# %%
#df = pd.read_table("facebook_combined.txt", sep = " ", names = ['source', 'target'], index_col=False)
df = pd.read_csv("soc-sign-bitcoinotc.csv", sep = ",", usecols=[0,1], names = ['source', 'target'], index_col=False)

# %%
df.shape
# Out:
# (35592, 2)

# %%
#Reduce the dataframe to 600 rows (including header)
df = df[:601]

# %%
df.head()
# Out:
#    source  target
# 0       6       2
# 1       6       5
# 2       1      15
# 3       4       3
# 4      13      16

# %%
df.shape
# Out:
# (601, 2)

# %% [markdown]
# 2. Create basic analysis on the graph, including the graph’s diameter, and at least one other metric of your choosing.  You may either code the functions by hand (to build your intuition and insight), or use functions in an existing package.

# %%
# Graph object
Gph = nx.from_pandas_edgelist(df)

# %%
# Diameter of the graph
nx.algorithms.diameter(Gph)
# Out:
# 7

# %%
# average shortest path
nx.algorithms.average_shortest_path_length(Gph)
# Out:
# 3.1144853150841176

# %% [markdown]
# 3. Use a visualization tool of your choice (Neo4j, Gephi, etc.) to display information.

# %%
# Visualization using Networkx
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
nx.draw(Gph, node_color='bisque', with_labels=True)
